# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_excel("Book.xlsx", index_col=0)

# %%
data = pd.read_excel("Book.xlsx", index_col=0)
greater_dict = []
for col in data:
    val_c = dict(enumerate(data[col].unique()))
    val_c['']=np.nan
    greater_dict.append(val_c)
    val_c = {v: k for k, v in val_c.items()}
    data[col] = data[col].map(val_c)

# %%
data.to_excel("done.xlsx")

# %%
greater_dict
# Out:
# [{0: 'Женский', '': nan},
#  {0: '18 – 24', 1: '25-40', 2: '41-55', 3: '56-64', '': nan},
#  {0: 'Да', 1: 'Нет смартфона (перейдите к вопросу 18)', 2: nan, '': nan},
#  {0: 'Да', 1: 'Нет (перейти к вопросу 19)', 2: nan, '': nan},
#  {0: nan,
#   1: 'Sony',
#   2: 'Samsung',
#   3: 'iPhone ',
#   4: 'Alcatel',
#   5: 'apple',
#   6: 'Nokia',
#   7: 'Apple',
#   8: 'YotaPhone',
#   9: 'Highscreen',
#   10: 'LG',
#   11: 'Asus',
#   12: 'Philips',
#   13: 'Huawei',
#   14: 'HTC',
#   15: 'wor(l)d',
#   16: 'IPhone',
#   17: 'Iphone',
#   18: 'Эпл',
#   19: 'Apple ',
#   20: 'HUAWEI',
#   21: 'Lenovo',
#   22: 'senseit',
#   '': nan},
#  {0: 'Android',
#   1: 'iOS ',
#   2: nan,
#   3: 'ios',
#   4: 'Windows Mobile',
#   5: 'IOS',
#   6: 'Windows Phone',
#   7: 'Ios',
#   8: 'iOS',
#   9: 'IOS ',
#   '': nan},
#  {0: '5.0" - 5.4"',
#   1: '3.5" - 4.5"',
#   2: '4.6" - 4.9"',
#   3: '5.5" - 5.9"',
#   4: 'Затрудняюсь ответить',
#   5: nan,
#   6: '6" и более',
#   '': nan},
#  {0: '3.1 - 8.0',
#   1: '12.1 - 16.0',
#   2: '8.1 - 12.0',
#   3: '16.1 и более',
#   4: nan,
#   5: 'Затрудняюсь ответить',
#   6: '0.3 - 3.0',
#   '': nan},
#  {0: '0.3 - 3.0',
#   1: '3.1 - 8.0',
#   2: '8.1 - 12.0',
#   3: 'Нет фронтальной камеры',
#   4: nan,
#   5: 'Затрудняюсь ответить',
#   6: '16.1 и более',
#   7: '12.0 - 16.0',
#   '': nan},
#  {0: '1.5 ГБ - 2 ГБ',
#   1: '768 МБ - 1 ГБ',
#   2: '3 ГБ и более',
#   3: 'Затрудняюсь ответить',
#   4: '256 МБ - 512 Мб',
#   5: nan,
#   '': nan},
#  {0: '8 ГБ - 16 ГБ',
#   1: '512 Мб - 4 ГБ',
#   2: nan,
#   3: 'Затрудняюсь ответить',
#   4: '32 ГБ - 64 ГБ',
#   '': nan},
#  {0: '2200 мАч – 3500 мАч',
#   1: '1715 мАч – 2100 мАч',
#   2: 'Затрудняюсь ответить',
#   3: '1100 мАч – 1700 мАч',
#   4: '3600 мАч – 5200 мАч',
#   5: nan,
#   6: '2200 мАч – 2750 мАч',
#   7: 'Более 5200 мАч',
#   '': nan},
#  {0: 'Из личных побуждений',
#   1: 'Из личных побуждений, Рекомендации продавца-консультанта',
#   2: 'Члены моей семьи пользуются данной маркой телефона',
#   3: 'Это подарок (по тем временам актуальный)',
#   4: nan,
#   5: 'Рекомендации продавца-консультанта',
#   6: 'Мои друзья пользуются данной маркой телефона',
#   7: 'Реклама',
#   8: 'Из личных побуждений, Реклама, заинтересовала новинка(телефон с 2 экранами)',
#   9: 'Из личных побуждений, Реклама',
#   10: 'Мои друзья пользуются данной маркой телефона, Из личных побуждений, Реклама',
#   11: 'Родители подарили на Новый год',
#   12: 'Родители подарили',
#   13: 'выбор родителей',
#   14: 'Члены моей семьи пользуются данной маркой телефона, Из личных побуждений',
#   15: 'Мои друзья пользуются данной маркой телефона, Из личных побуждений',
#   16: 'подарили',
#   17: 'сломался предыдущий',
#   18: 'Из личных побуждений, приемлемое соотношение цены и качества ',
#   19: 'Члены моей семьи пользуются данной маркой телефона, Рекомендации продавца-консультанта',
#   '': nan},
#  {0: 'Операционная система, Камера, Емкость батареи, Объем оперативной памяти, Низкая цена',
#   1: 'Внешний вид, Низкая цена',
#   2: 'Камера, Объем оперативной памяти, Низкая цена',
#   3: 'Размер дисплея, Внешний вид',
#   4: 'Операционная система, Камера, Емкость батареи, Объем оперативной памяти',
#   5: 'Бренд',
#   6: 'Размер дисплея, Камера, Внешний вид',
#   7: 'Операционная система, Камера, Объем оперативной памяти',
#   8: 'Операционная система, Камера, Емкость батареи',
#   9: 'Камера, Емкость батареи, Бренд',
#   10: nan,
#   11: 'Операционная система, Камера, Емкость батареи, Внешний вид, Объем оперативной памяти',
#   12: 'Внешний вид',
#   13: 'Камера, Емкость батареи, Внешний вид, Низкая цена',
#   14: 'Камера, Внешний вид',
#   15: 'Размер дисплея, Камера, Внешний вид, Низкая цена, GPS навигация',
#   16: 'Операционная система, Размер дисплея, Камера, Внешний вид, Бренд',
#   17: 'Операционная система, Внешний вид, Объем оперативной памяти, GPS навигация',
#   18: 'Операционная система, Внешний вид, Бренд',
#   19: 'Камера, Внешний вид, заинтересовала новинка(телефон с 2 экранами)',
#   20: 'Операционная система, Размер дисплея, Камера, Емкость батареи, «Лишь бы звонил»',
#   21: 'Камера',
#   22: 'Операционная система, Расширение дисплея',
#   23: 'Операционная система, Камера, Внешний вид, GPS навигация, Бренд',
#   24: 'Операционная система, Емкость батареи, Низкая цена',
#   25: 'Операционная система, Размер дисплея, Объем оперативной памяти',
#   26: 'Объем оперативной памяти, процессор',
#   27: 'Операционная система, Размер дисплея, Объем оперативной памяти, Бренд',
#   28: 'Операционная система, Размер дисплея, Камера, Внешний вид',
#   29: 'Емкость батареи, Низкая цена',
#   30: 'Операционная система, Внешний вид',
#   31: 'Операционная система, Размер дисплея, Камера, Емкость батареи, Низкая цена',
#   32: 'Операционная система, Размер дисплея, Низкая цена',
#   33: 'Операционная система, Камера, Внешний вид',
#   34: 'Емкость батареи, «Лишь бы звонил»',
#   35: 'Операционная система, Размер дисплея, Камера, Внешний вид, Объем оперативной памяти',
#   36: 'Размер дисплея, Камера, Емкость батареи, Низкая цена',
#   37: 'Хорошие отзывы',
#   38: 'Операционная система',
#   39: 'Операционная система, Камера, Внешний вид, Бренд',
#   40: 'Операционная система, Емкость батареи, Внешний вид, Низкая цена, «Лишь бы звонил»',
#   41: 'Камера, Емкость батареи, Внешний вид, Объем оперативной памяти',
#   42: 'Операционная система, Камера, Емкость батареи, Внешний вид',
#   43: 'Камера, Внешний вид, Бренд',
#   44: 'Операционная система, Размер дисплея, Камера, Емкость батареи',
#   45: 'Операционная система, Размер дисплея, Объем оперативной памяти, Низкая цена',
#   46: 'Размер дисплея, Внешний вид, Объем оперативной памяти',
#   47: '«Лишь бы звонил»',
#   48: 'Операционная система, Камера, Внешний вид, «Лишь бы звонил», Бренд',
#   49: 'Емкость батареи, Внешний вид, две сим-карты',
#   50: 'Размер дисплея, Камера, Емкость батареи, Внешний вид, Объем оперативной памяти',
#   51: 'Внешний вид, Низкая цена, «Лишь бы звонил»',
#   52: 'Размер дисплея, Камера, Внешний вид, «Лишь бы звонил»',
#   53: 'Камера, Объем оперативной памяти, Бренд',
#   54: 'Камера, Емкость батареи, Низкая цена',
#   55: 'Операционная система, Размер дисплея, Внешний вид',
#   56: 'Камера, Емкость батареи, Внешний вид, Объем оперативной памяти, Низкая цена',
#   57: 'Камера, Емкость батареи, Внешний вид',
#   58: 'Операционная система, Емкость батареи, Внешний вид, Объем оперативной памяти, Низкая цена',
#   59: 'Размер дисплея, Камера, Внешний вид, Объем оперативной памяти',
#   60: 'Операционная система, Камера, Емкость батареи, Внешний вид, Низкая цена',
#   61: 'Операционная система, Размер дисплея, Камера, Емкость батареи, Внешний вид',
#   62: 'Размер дисплея, Камера, Низкая цена',
#   '': nan},
#  {0: 'Доступ к Интернету, Коммуникация, Слушание музыки',
#   1: 'Доступ к Интернету, Коммуникация',
#   2: 'Доступ к Интернету, Карты, навигация, Чтение электронных книг',
#   3: 'Доступ к Интернету, Карты, навигация, Слушание музыки',
#   4: 'Доступ к Интернету, Карты, навигация, Коммуникация',
#   5: nan,
#   6: 'Все перечисленное',
#   7: 'Доступ к Интернету, Коммуникация, Слушание музыки, просмотр фильмов',
#   8: 'Доступ к Интернету, Слушание музыки, просмотр фильмов, Чтение электронных книг',
#   9: 'Доступ к Интернету, Коммуникация, Игры',
#   10: 'Доступ к Интернету',
#   11: 'Доступ к Интернету, Коммуникация, Чтение электронных книг',
#   12: 'Доступ к Интернету, Игры, Слушание музыки',
#   13: 'никак, он настолько стар, что выключается через 5 минут, неважно каких, и даже если заряд батареи 100%',
#   14: 'Доступ к Интернету, Слушание музыки, Чтение электронных книг',
#   15: 'Доступ к Интернету, Карты, навигация',
#   16: 'Доступ к Интернету, Слушание музыки',
#   17: 'Доступ к Интернету, Игры, Чтение электронных книг',
#   18: 'Игры, Слушание музыки, Просмотр фильмов',
#   19: 'Коммуникация, Слушание музыки, Чтение электронных книг',
#   '': nan},
#  {0: 'Покупаю телефон по низкой цене, когда выходит новая модель',
#   1: 'Покупаю телефон, когда что-то случается со старым, не особо долго выбирая из того, что есть в данный момент в магазинах',
#   2: nan,
#   3: 'Стараюсь немного подождать, пока упадет цена',
#   4: 'Затрудняюсь ответить)',
#   5: 'Подарили ',
#   6: 'Не слежу за ценовой политикой',
#   7: 'По потребности',
#   8: 'Покупаю телефон, как только он выходит, несмотря на высокую цену',
#   9: 'Не следу за ценами. Беру то, что нравится',
#   10: 'По мере необходимости покупки в доступной ценовой категории',
#   11: 'по соотношению цена-качество',
#   12: 'покупаю телефон, когда перестает нормально функционировать старый',
#   13: 'Как сломается предыдущий',
#   14: 'выбираю по нужным мне функциям',
#   15: 'мне подарили!',
#   16: 'сравнение характеристик различных смартфонов',
#   17: 'Нужен телефон-беру',
#   '': nan},
#  {0: 'Да, примерно раз в месяц',
#   1: 'Не слежу вообще',
#   2: 'Да, постоянно просматриваю новости',
#   3: nan,
#   4: 'Да, раз в неделю',
#   '': nan},
#  {0: 'Примерно раз в 2-3 года',
#   1: 'Не приходилось менять устройство',
#   2: 'Затрудняюсь ответить',
#   3: nan,
#   4: 'Примерно раз в год',
#   5: 'Несколько раз в год',
#   6: 'когда сломается, тогда меняю',
#   7: 'Как сломается или устареет (Раз в 5 лет)',
#   8: 'раз в 5 лет',
#   9: 'Раз в 4-5 лет',
#   10: 'раз в 3-4 года',
#   11: 'когда ломаются или терябтся',
#   12: 'когда полностью сдыхает =)',
#   13: 'Раз в 3 - 5 лет',
#   '': nan},
#  {0: 'Хорошее',
#   1: 'Превосходное',
#   2: 'Скорее плохое',
#   3: 'Очень плохое',
#   4: nan,
#   5: 'Скорее хорошее',
#   '': nan},
#  {0: nan,
#   1: 'Использую только основные функции телефона, нет необходимости приобретать смартфон',
#   2: 'Недостаточно средств для покупки',
#   3: 'Мобильное устройство сложно в освоении',
#   '': nan},
#  {0: 'До 25 000 рублей',
#   1: '25 000 – 50 000 рублей',
#   2: '50 001 – 100 000 рублей',
#   3: 'Более 100 000 рублей',
#   4: nan,
#   '': nan},
#  {0: 'Среднее',
#   1: 'Высшее профессиональное',
#   2: 'Основное',
#   3: 'Средне специальное',
#   4: 'Без образования или неполное основное образование',
#   5: 'Ученая степень (магистр, кандидат, доктор наук и эквивалентное)',
#   '': nan},
#  {0: 'Работаю',
#   1: 'Не работаю, ищу работу',
#   2: 'Не работаю и не ищу работу',
#   '': nan},
#  {0: 'Не замужем / не \xa0женат', 1: 'Замужем / женат', '': nan},
#  {0: 'Нет детей', 1: '1 ребёнок', 2: '2 ребёнка', 3: '3-4 ребёнка', '': nan}]
